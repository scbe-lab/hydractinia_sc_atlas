# %% [markdown]
# ## Setting up the google colab (optional)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install numpy
# !pip install pandas
# !pip install scanpy
# !pip install scanpy.external
# !pip install harmonypy
# !pip install seaborn
# !pip install mudata
# !pip install muon
# !pip install mudatasets
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting scanpy
#   Downloading scanpy-1.9.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 9.2 MB/s eta 0:00:00
# Collecting anndata>=0.7.4 (from scanpy)
#   Downloading anndata-0.9.2-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.2/104.2 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.23.5)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.7.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.5.3)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.10.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.12.2)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from scanpy) (4.66.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.2.2)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.14.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.5.3)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.3.2)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.56.4)
# Collecting umap-learn>=0.3.10 (from scanpy)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from scanpy) (23.1)
# Collecting session-info (from scanpy)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.41.0->scanpy) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.41.0->scanpy) (67.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->scanpy) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->scanpy) (3.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy->scanpy) (1.16.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.3.10->scanpy)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting stdlib_list (from session-info->scanpy)
#   Downloading stdlib_list-0.9.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.8 MB/s eta 0:00:00
# Building wheels for collected packages: umap-learn, session-info, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82808 sha256=bf8fa6d1212eb66429832b8e7f84c0ca152c84151a4f8a483418b33c9f93ffd4
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8027 sha256=c9670c25c4913e8b23438b1ee608157b5a110298bec12f641590f7a901d3f0df
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55617 sha256=0d363ba925a6b2cd3207d28650f19d0b93fad7373239378bb2f6e336e5b9a896
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built umap-learn session-info pynndescent
# Installing collected packages: stdlib_list, session-info, pynndescent, anndata, umap-learn, scanpy
# Successfully installed anndata-0.9.2 pynndescent-0.5.10 scanpy-1.9.3 session-info-1.0.0 stdlib_list-0.9.0 umap-learn-0.5.3
# ERROR: Could not find a version that satisfies the requirement scanpy.external (from versions: none)
# ERROR: No matching distribution found for scanpy.external
# Collecting harmonypy
#   Downloading harmonypy-0.0.9-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from harmonypy) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from harmonypy) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from harmonypy) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from harmonypy) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->harmonypy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->harmonypy) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->harmonypy) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->harmonypy) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->harmonypy) (1.16.0)
# Installing collected packages: harmonypy
# Successfully installed harmonypy-0.0.9
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Collecting mudata
#   Downloading mudata-0.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mudata) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mudata) (1.5.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from mudata) (3.9.0)
# Requirement already satisfied: anndata>=0.8 in /usr/local/lib/python3.10/dist-packages (from mudata) (0.9.2)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->mudata) (1.10.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->mudata) (8.4.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->mudata) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mudata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mudata) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->mudata) (1.16.0)
# Installing collected packages: mudata
# Successfully installed mudata-0.2.3
# Collecting muon
#   Downloading muon-0.1.5-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.7/292.7 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from muon) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from muon) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from muon) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from muon) (0.12.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from muon) (3.9.0)
# Requirement already satisfied: anndata in /usr/local/lib/python3.10/dist-packages (from muon) (0.9.2)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.10/dist-packages (from muon) (1.9.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from muon) (1.2.2)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (from muon) (0.5.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from muon) (0.56.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from muon) (3.20.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from muon) (4.66.0)
# Requirement already satisfied: mudata in /usr/local/lib/python3.10/dist-packages (from muon) (0.2.3)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.10/dist-packages (from anndata->muon) (1.10.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from anndata->muon) (8.4.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from anndata->muon) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->muon) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->muon) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon) (3.1.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->muon) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->muon) (67.7.2)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.10/dist-packages (from scanpy->muon) (0.14.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy->muon) (0.5.3)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.10/dist-packages (from scanpy->muon) (3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy->muon) (1.3.2)
# Requirement already satisfied: session-info in /usr/local/lib/python3.10/dist-packages (from scanpy->muon) (1.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->muon) (3.2.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn->muon) (0.5.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->muon) (1.16.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.10/dist-packages (from session-info->scanpy->muon) (0.9.0)
# Installing collected packages: muon
# Successfully installed muon-0.1.5
# Collecting mudatasets
#   Downloading mudatasets-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: mudata in /usr/local/lib/python3.10/dist-packages (from mudatasets) (0.2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mudatasets) (4.66.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mudatasets) (2.31.0)
# Requirement already satisfied: muon in /usr/local/lib/python3.10/dist-packages (from mudatasets) (0.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mudata->mudatasets) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mudata->mudatasets) (1.5.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from mudata->mudatasets) (3.9.0)
# Requirement already satisfied: anndata>=0.8 in /usr/local/lib/python3.10/dist-packages (from mudata->mudatasets) (0.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from muon->mudatasets) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from muon->mudatasets) (0.12.2)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.10/dist-packages (from muon->mudatasets) (1.9.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from muon->mudatasets) (1.2.2)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (from muon->mudatasets) (0.5.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from muon->mudatasets) (0.56.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from muon->mudatasets) (3.20.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mudatasets) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mudatasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mudatasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mudatasets) (2023.7.22)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->mudata->mudatasets) (1.10.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->mudata->mudatasets) (8.4.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->mudata->mudatasets) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mudata->mudatasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mudata->mudatasets) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon->mudatasets) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon->mudatasets) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon->mudatasets) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon->mudatasets) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon->mudatasets) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->muon->mudatasets) (3.1.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->muon->mudatasets) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->muon->mudatasets) (67.7.2)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.10/dist-packages (from scanpy->muon->mudatasets) (0.14.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy->muon->mudatasets) (0.5.3)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.10/dist-packages (from scanpy->muon->mudatasets) (3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy->muon->mudatasets) (1.3.2)
# Requirement already satisfied: session-info in /usr/local/lib/python3.10/dist-packages (from scanpy->muon->mudatasets) (1.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->muon->mudatasets) (3.2.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn->muon->mudatasets) (0.5.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->mudata->mudatasets) (1.16.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.10/dist-packages (from session-info->scanpy->muon->mudatasets) (0.9.0)
# Installing collected packages: mudatasets
# Successfully installed mudatasets-0.0.2

# %% [markdown]
# ## Importing modules and settings

# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import mudata as md
import muon as mu
import mudatasets as mds
import seaborn as sns
import scanpy.external as sce

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# General settings of Scanpy

# %%
sc.settings.verbosity = 3
sc.logging.print_header()
sc.settings.set_figure_params(dpi=300, transparent = True, format = 'pdf', vector_friendly = True)
# Out:
# scanpy==1.9.1 anndata==0.8.0 umap==0.5.2 numpy==1.22.4 scipy==1.10.1 pandas==1.4.3 scikit-learn==1.0.2 statsmodels==0.13.2 python-igraph==0.10.4 louvain==0.7.1 pynndescent==0.5.6

# %%
umap_cmap = sns.blend_palette(['lightgrey', 'xkcd:sapphire'], as_cmap = True)

# %% [markdown]
# ## Functions for diamond blast querying

# %% [markdown]
# This set of functions explores the diamond blast annotation to return the most informative hit. It works like this:
# if there is a hit of the 'preferred species' in the diamond, it returns this one. The preferred species is coded below as "Hydra" in the default
# Otherwise, it looks for an informative hit, this means avoiding hits like "hypothetical protein", etc. These are coded in the list of words (words to avoid). If there is no such nice hit it returns "no nice hit:" followed by the best hit by pvalue, that will then contain either "hypothetical" etc. If there are no hits in the diamond, it returns "not in Diamond"

# %%
def check_for_species(df, species):
    mask = df['match'].str.contains(species, na=False)
    if mask.any():
        contained = df.loc[mask].sort_values('match')
        return contained.iloc[0, 1]
    else:
        return None

# %%
def contains_words (hit_string, li):
    ret = False
    for word in li:
    #print(word)
        if word.lower() in hit_string:
        #print(word)
            ret = True
    return ret

# %%
def get_informative(df, li):
    if len(df.index) == 0:
        return "not in Diamond"
    else:
        for i, row in df.iterrows():
            se = row[1]
            if isinstance(se, str) and not contains_words(se.lower(), li):
                return se
        return "no informative hits: " + str(df.iloc[0, 1])

# %%
def get_best_hit (transcript, species, li):
    search = diamond[diamond['gene_id'] == transcript]
    if check_for_species(search, species) is not None:
        return check_for_species(search, species)
    else:
        return get_informative (search, li)
###########################################################

# %%
def check_for_species_2(df, species):
    mask = df['ncbi_name'].str.contains(species, na=False)
    if mask.any():
        contained = df.loc[mask].sort_values('ncbi_name')
        return contained.iloc[0, 2]
    else:
        return None

# %%
def get_informative_2(df, li):
    if len(df.index) == 0:
        return "other RNA"
    else:
        for i, row in df.iterrows():
            se = row[1]
            if isinstance(se, str) and not contains_words(se.lower(), li):
                return se
        return str(df.iloc[0, 2])

# %%
def get_best_hit_2 (transcript, species, li):
    search = diamond[diamond['gene_id'] == transcript]
    if check_for_species_2(search, species) is not None:
        return check_for_species_2(search, species)
    else:
        return get_informative_2 (search, li)

# %%
preferred_species = 'Hydra'

# %%
preferred_species_2 = 'Hydractinia'

# %%
list_of_words = ['hypothetical', 'uncharacterized', 'unnamed']

# %%
diamond=  pd.read_csv('/mnt/sda/david/interpro_diamond_blast/hydractinia_only/recip_blasts/20230711_equivalence_gene_protein_diamond_ncbi.tsv', sep='\t', usecols=[1,6,7])#, skiprows=1)

# %%
diamond
# Out:
#              gene_id                                              match  \
# 0       LOC130612030                                                NaN
# 1       LOC130612031                                                NaN
# 2       LOC130612032  XP_012562270.1 PREDICTED: thymidylate synthase...
# 3       LOC130612032  ACS44779.1 thymidylate synthase [Penaeus vanna...
# 4       LOC130612032  6K7Q_A Crystal structure of thymidylate syntha...
# ...              ...                                                ...
# 559870  LOC130662872  XP_004209014.1 PREDICTED: uncharacterized prot...
# 559871  LOC130662872  XP_004205780.1 PREDICTED: uncharacterized prot...
# 559872  LOC130662872  XP_002162793.1 PREDICTED: 52 kDa repressor of ...
# 559873  LOC130662872  XP_004207246.1 PREDICTED: uncharacterized prot...
# 559874  LOC130662872  XP_002165593.2 PREDICTED: uncharacterized prot...
#
#                                                 ncbi_name
# 0       melatonin receptor type 1C-like [Hydractinia s...
# 1       circumsporozoite protein-like [Hydractinia sym...
# 2       thymidylate synthase-like [Hydractinia symbiol...
# 3       thymidylate synthase-like [Hydractinia symbiol...
# 4       thymidylate synthase-like [Hydractinia symbiol...
# ...                                                   ...
# 559870  52 kDa repressor of the inhibitor of the prote...
# 559871  52 kDa repressor of the inhibitor of the prote...
# 559872  52 kDa repressor of the inhibitor of the prote...
# 559873  52 kDa repressor of the inhibitor of the prote...
# 559874  52 kDa repressor of the inhibitor of the prote...
#
# [559875 rows x 3 columns]

# %% [markdown]
# ## Declaring the input and output files

# %%
mdata = mu.read('/mnt/sda/david/hydractinia/hydractinia_atlas_20230812.h5mu')
# Out:
# /mnt/sda/david/.local/lib/python3.8/site-packages/mudata/_core/mudata.py:457: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(

# %%
adata= (mdata.mod['no'])

# %%
name_of_analysis = 'hysim_atlas'

# %%
leiden_names = adata.obs.columns[adata.obs.columns.str.contains('leiden')].to_list()

# %%
leiden_names
# Out:
# ['leiden_1', 'leiden_1.5', 'leiden_2']

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 199113 × 18061
#     obs: 'Experiment', 'Library', 'Body_part', 'Presence_of_PEG', 'batch', 'n_counts', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden_1', 'leiden_1.5', 'leiden_2', 'Colony_part', 'Unique'
#     var: 'ratio_with_no', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'Library_colors', 'dendrogram_leiden_1.5', 'hvg', 'leiden', 'leiden_1.5_colors', 'leiden_1_colors', 'leiden_2_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups_logreg_leiden_1', 'rank_genes_groups_logreg_leiden_1.5', 'rank_genes_groups_logreg_leiden_2', 'rank_genes_groups_wilcox_leiden_1', 'rank_genes_groups_wilcox_leiden_1.5', 'rank_genes_groups_wilcox_leiden_2', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
leiden_names_selected = leiden_names

# %%
leiden_names_selected
# Out:
# ['leiden_1', 'leiden_1.5', 'leiden_2']

# %%
clusteringlayer = 'leiden_1.5'

# %%
os.mkdir('/mnt/sda/david/hydractinia/Supplementary_Files/'+name_of_analysis+'_marker_pdfs_and_excels_supp')

# %%
with pd.ExcelWriter('/mnt/sda/david/hydractinia/Supplementary_Files/'+name_of_analysis+'_marker_pdfs_and_excels_supp/'+clusteringlayer+'_markers_overlap_supp.xlsx') as writer:
# change directory
    for i in adata.obs[clusteringlayer].cat.categories:

        lfc_s = pd.Series(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['logfoldchanges'][i])
        pval_s = pd.Series(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['pvals'][i])
        he_m = max(list(set(pval_s[pval_s < 0.05].index.to_list()) & set(lfc_s[lfc_s > 0].index.to_list())))

        a = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['names']).head(he_m)[i].rename('names')
        b = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['logfoldchanges']).head(he_m)[i].rename('logfoldchanges')
        c = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['pvals']).head(he_m)[i].rename('pvals')
        d = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['pvals_adj']).head(he_m)[i].rename('pvals_adj')
        e = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['scores']).head(he_m)[i].rename('scores')
        f = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['names']).head(he_m)[i].apply(get_best_hit, args=(preferred_species, list_of_words)).rename('diamond')
        g = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['names']).head(he_m)[i].apply(get_best_hit_2, args=(preferred_species_2, list_of_words)).rename('ncbi_name')
        df = pd.concat([a, b, c, d, e, f, g], axis = 1)
        df.to_excel(writer, sheet_name='Cluster '+i)
# Out:
# Exception ignored in: <function ZipFile.__del__ at 0x7f871c950b80>
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/zipfile.py", line 1821, in __del__
#     self.close()
#   File "/usr/lib/python3.8/zipfile.py", line 1838, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file

# %%
os.mkdir('/mnt/sda/david/hydractinia/Supplementary_Files/'+name_of_analysis+'_marker_wilcox_pdfs_and_excels/')

# %%
with pd.ExcelWriter('/mnt/sda/david/hydractinia/Supplementary_Files/'+name_of_analysis+'_marker_wilcox_pdfs_and_excels/'+clusteringlayer+'_markers_wilcoxon.xlsx') as writer:
# change directory
    for i in adata.obs[clusteringlayer].cat.categories:
        lfc_s = pd.Series(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['logfoldchanges'][i])
        pval_s = pd.Series(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['pvals'][i])
        he_m = max(list(set(pval_s[pval_s < 0.05].index.to_list()) & set(lfc_s[lfc_s > 0].index.to_list())))


        a = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['names']).head(he_m)[i].rename('names')
        b = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['logfoldchanges']).head(he_m)[i].rename('logfoldchanges')
        c = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['pvals']).head(he_m)[i].rename('pvals')
        d = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['pvals_adj']).head(he_m)[i].rename('pvals_adj')
        e = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['scores']).head(he_m)[i].rename('scores')
        f = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['names']).head(he_m)[i].apply(get_best_hit, args=(preferred_species, list_of_words)).rename('diamond')
        g = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['names']).head(he_m)[i].apply(get_best_hit_2, args=(preferred_species_2, list_of_words)).rename('ncbi_name')
        df = pd.concat([a, b, c, d, e, f, g], axis = 1)
        df.to_excel(writer, sheet_name='Cluster '+i)

# %%
os.mkdir('/mnt/sda/david/hydractinia/Supplementary_Files/'+name_of_analysis+'_marker_logreg_pdfs_and_excels/')

# %%
with pd.ExcelWriter('/mnt/sda/david/hydractinia/Supplementary_Files/'+name_of_analysis+'_marker_logreg_pdfs_and_excels/'+clusteringlayer+'_markers.xlsx') as writer:
        for i in adata.obs[clusteringlayer].cat.categories:
            a = pd.DataFrame(adata.uns['rank_genes_groups_logreg_'+clusteringlayer]['names']).head(30)[i].rename('names')
            b = pd.DataFrame(adata.uns['rank_genes_groups_logreg_'+clusteringlayer]['scores']).head(30)[i].rename('scores')
            c = pd.DataFrame(adata.uns['rank_genes_groups_logreg_'+clusteringlayer]['names']).head(30)[i].apply(get_best_hit, args=(preferred_species, list_of_words)).rename('diamond')
            d = pd.DataFrame(adata.uns['rank_genes_groups_logreg_'+clusteringlayer]['names']).head(30)[i].apply(get_best_hit_2, args=(preferred_species_2, list_of_words)).rename('ncbi_name')
            df = pd.concat([a, b, c, d], axis = 1)
            df.to_excel(writer, sheet_name='Cluster '+i)

# %%
def get_plots (ad,clusteringlayer, cluster, li_markers):
    fig, axs = plt.subplots(4, 4, figsize = (15, 15))

    sc.pl.umap(adata, color= clusteringlayer, legend_loc = 'on data', groups = cluster, na_in_legend = False, size = 5, legend_fontsize = 7, title = clusteringlayer+' cluster '+cluster, show = False, ax = axs[0, 0])



    while len(li_markers) < 15:
        li_markers.append(None)

    gene01 = li_markers[0]
    gene02 = li_markers[1]
    gene03 = li_markers[2]
    gene10 = li_markers[3]
    gene11 = li_markers[4]
    gene12 = li_markers[5]
    gene13 = li_markers[6]
    gene20 = li_markers[7]
    gene21 = li_markers[8]
    gene22 = li_markers[9]
    gene23 = li_markers[10]
    gene30 = li_markers[11]
    gene31 = li_markers[12]
    gene32 = li_markers[13]
    gene33 = li_markers[14]



    #Row 0 first row
    sc.pl.umap(ad, color= gene01, title = gene01, color_map = umap_cmap, show = False, ax = axs[0, 1])
    sc.pl.umap(ad, color= gene02, title = gene02, color_map = umap_cmap, show = False, ax = axs[0, 2])
    sc.pl.umap(ad, color= gene22, title = gene03, color_map = umap_cmap, show = False, ax = axs[0, 3])


    #Row 1 second row

    sc.pl.umap(ad, color= gene10, title = gene10, color_map = umap_cmap, show = False, ax = axs[1, 0])
    sc.pl.umap(ad, color= gene11, title = gene11, color_map = umap_cmap, show = False, ax = axs[1, 1])
    sc.pl.umap(ad, color= gene12, title = gene12, color_map = umap_cmap, show = False, ax = axs[1, 2])
    sc.pl.umap(ad, color= gene22, title = gene13, color_map = umap_cmap, show = False, ax = axs[1, 3])


    #Row 2 third row

    sc.pl.umap(ad, color= gene20, title = gene20, color_map = umap_cmap, show = False, ax = axs[2, 0])
    sc.pl.umap(ad, color= gene21, title = gene21, color_map = umap_cmap, show = False, ax = axs[2, 1])
    sc.pl.umap(ad, color= gene22, title = gene22, color_map = umap_cmap, show = False, ax = axs[2, 2])
    sc.pl.umap(ad, color= gene23, title = gene22, color_map = umap_cmap, show = False, ax = axs[2, 3])

    #Row 3 fourth row

    sc.pl.umap(ad, color= gene30, title = gene30, color_map = umap_cmap, show = False, ax = axs[3, 0])
    sc.pl.umap(ad, color= gene31, title = gene31, color_map = umap_cmap, show = False, ax = axs[3, 1])
    sc.pl.umap(ad, color= gene32, title = gene32, color_map = umap_cmap, show = False, ax = axs[3, 2])
    sc.pl.umap(ad, color= gene22, title = gene33, color_map = umap_cmap, show = False, ax = axs[3, 3])

    #new_fig = fig
    #plt.close(fig)
    #fig.clf()
    return fig
    plt.close(fig)

# %%
for i in adata.obs[clusteringlayer].cat.categories:
    li = []
    lfc_s = pd.Series(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['logfoldchanges'][i])
    pval_s = pd.Series(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['pvals'][i])
    he_m = max(list(set(pval_s[pval_s < 0.05].index.to_list()) & set(lfc_s[lfc_s > 0].index.to_list())))
    wl = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['names']).head(he_m)[i]
    lr = pd.DataFrame(adata.uns['rank_genes_groups_logreg_'+clusteringlayer]['names']).head(80)[i]
    li = wl[wl.isin(lr)].to_list()
    figure = get_plots(adata, clusteringlayer, i, li)
    figure.savefig('/mnt/sda/david/hydractinia/Supplementary_Files/'+name_of_analysis+'_marker_pdfs_and_excels_supp/umap_'+clusteringlayer+'_cluster_'+i+'.pdf',format = 'pdf')
    figure.clf()
    plt.close(figure)
# Out:
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)

# %%
for i in adata.obs[clusteringlayer].cat.categories:
        li = []
        mark = pd.DataFrame(adata.uns['rank_genes_groups_wilcox_'+clusteringlayer]['names']).head(15)[i]#or 'rank_genes_groups_wilcox' dependending which one is going to be calculated
        li = mark.to_list()
        figure = get_plots(adata, clusteringlayer, i, li)
        figure.savefig('/mnt/sda/david/hydractinia/Supplementary_Files/'+name_of_analysis+'_marker_wilcox_pdfs_and_excels/umap_'+clusteringlayer+'_cluster_'+i+'.pdf',format = 'pdf')# same here for each respective folder
        figure.clf()
        plt.close(figure)
# Out:
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)

# %%
for i in adata.obs[clusteringlayer].cat.categories:
        li = []
        mark = pd.DataFrame(adata.uns['rank_genes_groups_logreg_'+clusteringlayer]['names']).head(15)[i]#or 'rank_genes_groups_wilcox' dependending which one is going to be calculated
        li = mark.to_list()
        figure = get_plots(adata, clusteringlayer, i, li)
        figure.savefig('/mnt/sda/david/hydractinia/Supplementary_Files/'+name_of_analysis+'_marker_logreg_pdfs_and_excels/umap_'+clusteringlayer+'_cluster_'+i+'.pdf',format = 'pdf')# same here for each respective folder
        figure.clf()
        plt.close(figure)
# Out:
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# /mnt/sda/david/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
